# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\test_images\\harry.jpg")
img.shape
# Out:
# (768, 1024, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (768, 1024)

# %%
gray
# Out:
# array([[65, 63, 61, ..., 54, 56, 60],
#        [59, 58, 58, ..., 54, 55, 59],
#        [53, 55, 56, ..., 59, 60, 64],
#        ...,
#        [13, 11,  9, ..., 32, 32, 32],
#        [11, 10,  9, ..., 32, 33, 33],
#        [ 9,  9,  8, ..., 29, 29, 28]], dtype=uint8)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./opencv/haarcascades/haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray, 1.3, 5)
faces
# Out:
# array([[468, 112, 203, 203]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (468, 112, 203, 203)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    if img is not None:
        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
        faces = face_cascade.detectMultiScale(gray, 1.3, 5)
        for (x,y,w,h) in faces:
            roi_gray = gray[y:y+h, x:x+w]
            roi_color = img[y:y+h, x:x+w]
            eyes = eye_cascade.detectMultiScale(roi_gray)
            if len(eyes) >= 2:
                            return roi_color

# %%
original_image = cv2.imread("C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\test_images\\harry.jpg")
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes("C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\test_images\\harry.jpg")
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread("C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\test_images\\harry1.jpg")
plt.imshow(org_image_obstructed)

# %%
cropped_image_no_2_eyes = get_cropped_image_if_2_eyes("C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\test_images\\harry1.jpg")
cropped_image_no_2_eyes

# %%
path_to_data = "C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset"
path_to_cr_data = "C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\cropped"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\albus_dumbledore',
#  'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\hagrid',
#  'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\harry_potter',
#  'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\hermione_granger',
#  'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\minerva_mcgonagall']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('dataset\\')[-1]
    print(celebrity_name)
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# albus_dumbledore
# Generating cropped images in folder:  C:\Users\rupas\OneDrive\Desktop\Rupa Programs jupyter\SportsPersonClassifier\model\dataset\croppedalbus_dumbledore
# hagrid
# Generating cropped images in folder:  C:\Users\rupas\OneDrive\Desktop\Rupa Programs jupyter\SportsPersonClassifier\model\dataset\croppedhagrid
# harry_potter
# Generating cropped images in folder:  C:\Users\rupas\OneDrive\Desktop\Rupa Programs jupyter\SportsPersonClassifier\model\dataset\croppedharry_potter
# hermione_granger
# Generating cropped images in folder:  C:\Users\rupas\OneDrive\Desktop\Rupa Programs jupyter\SportsPersonClassifier\model\dataset\croppedhermione_granger
# minerva_mcgonagall
# Generating cropped images in folder:  C:\Users\rupas\OneDrive\Desktop\Rupa Programs jupyter\SportsPersonClassifier\model\dataset\croppedminerva_mcgonagall

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har, cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'albus_dumbledore': ['C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore1.png',
#   'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore2.png',
#   'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore3.png',
#   'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore4.png',
#   'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore5.png',
#   'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore6.png',
# ...

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'albus_dumbledore': 0,
#  'hagrid': 1,
#  'harry_potter': 2,
#  'hermione_granger': 3,
#  'minerva_mcgonagall': 4}

# %%
celebrity_file_names_dict
# Out:
# {'albus_dumbledore': ['C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore1.png',
#   'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore2.png',
#   'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore3.png',
#   'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore4.png',
#   'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore5.png',
#   'C:\\Users\\rupas\\OneDrive\\Desktop\\Rupa Programs jupyter\\SportsPersonClassifier\\model\\dataset\\croppedalbus_dumbledore/albus_dumbledore6.png',
# ...

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
32*32*3 + 32*32
# Out:
# 4096

# %%
len(X[0])
# Out:
# 4096

# %%
y[0]
# Out:
# 0

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (196, 4096)

# %%
X[0]
# Out:
# array([  8.,   4.,   9., ..., 202.,  52., 207.])

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C =10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8163265306122449

# %%
print(classification_report(y_test, pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.60      0.75         5
#            1       1.00      1.00      1.00         5
#            2       0.75      0.86      0.80        14
#            3       0.77      1.00      0.87        17
#            4       1.00      0.38      0.55         8
#
#     accuracy                           0.82        49
#    macro avg       0.90      0.77      0.79        49
# weighted avg       0.85      0.82      0.80        49

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.829655
# 1        random_forest    0.667126
# 2  logistic_regression    0.823908
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8163265306122449

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.673469387755102

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8163265306122449

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 4,  0,  0,  1,  0],
#        [ 0,  5,  0,  0,  0],
#        [ 1,  0, 11,  0,  2],
#        [ 0,  0,  0, 16,  1],
#        [ 0,  0,  2,  2,  4]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'albus_dumbledore': 0,
#  'hagrid': 1,
#  'harry_potter': 2,
#  'hermione_granger': 3,
#  'minerva_mcgonagall': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# ...
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
